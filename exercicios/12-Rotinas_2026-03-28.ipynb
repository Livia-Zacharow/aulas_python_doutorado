# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Cite três vantagens do uso das funções e duas características que toda função deva ter?

# %% [markdown]
# R.: O uso de funções é vantajoso pois otimiza processamento, uma vez que não executa tudo simultaneamente, um segundo objetivo é a usabilidade, pois consegue reutilizar o mesmo código e é fácil de corrigir, pois corrige somente em um lugar. Uma função deve possuir parâmetros para receber dados e retornar valores.

# %% [markdown]
# ## Responda a pergunta do exercício 2 da aula 10, usando funções:<br>
# Instancie um objeto da classe NumPy array, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.<br><br>
# Quantos e quais são os valores superiores a 10?

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: 1 - recebe um array
# 2 - cria o objeto "maiores"
# 3 - filtra todos os valores do array que são maiores que zero e coloca dentro do objeto
# 4 - cria o objeto "quantidades"
# 5 - calcula quantos valores estão dentro de "maiores"
# 6 - retorna ambos os objetos

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/lista12_exercicio3.png" width="400" />

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
import numpy as np

# %%
array_ex4 = np.random.normal(10, 3, 5)
array_ex4
# Out:
# array([ 6.17496068, 10.53194619,  7.20238977, 13.1128737 ,  5.68399585])

# %%
def dez(array):
    maiores = array[array > 10]
    quantidade = len(maiores)
    return f"""
Quantidade: {quantidade}
Valores: {maiores}
"""

# %%
print(dez(array_ex4))
# Out:
# Quantidade: 2
# Valores: [10.53194619 13.1128737 ]

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %% [markdown]
# Não. Teria que alterar a função ou criar uma nova. Por exemplo:

# %%
def vinte(array):
    maiores = array[array > 20]
    quantidade = len(maiores)
    return f"""
Quantidade: {quantidade}
Valores: {maiores}
"""

# %%
print(vinte(array_ex4))
# Out:
# Quantidade: 0
# Valores: []

# %% [markdown]
# ## Desenvolva um programa de computador que retorne a média de um conjunto de valores.

# %% [markdown]
# ## 06 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: 1 - somar todos os valores
# 2 - calcular quantidade de valores
# 3 - razão entre soma e quantidade
# 4 - retornar média

# %% [markdown]
# ## 07 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/lista12_exercicio7.png" width="400" />

# %% [markdown]
# ## 07 – Escreva o programa em Python:

# %%
def calcular_media(lista):
    soma = sum(lista)
    quantidade = len(lista)
    media = soma / quantidade
    return media

# %%
valores = np.random.randint(0, 100, 7).tolist()
valores
# Out:
# [29, 34, 64, 85, 40, 80, 47]

# %%
print(calcular_media(valores))
# Out:
# 40.0

# %% [markdown]
# ## 09 – Desenvolva um programa de computador que retorne a divisão de dois objetos simples. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def dividir_simples(a, b):
    print("a:", type(a))
    print("b:", type(b))
    resultado = a / b
    print("resultado:", type(resultado))
    return resultado

# %%
print(dividir_simples(10, 2))
# Out:
# a: <class 'int'>
# b: <class 'int'>
# resultado: <class 'float'>
# 5.0

# %%
print(dividir_simples(4564.854, 27.2757))
# Out:
# a: <class 'float'>
# b: <class 'float'>
# resultado: <class 'float'>
# 167.35973778858104

# %% [markdown]
# ## 10 – Desenvolva um programa de computador que retorne a divisão de dois objetos compostos. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def dividir_listas(c, d):
    print("c:", type(c))
    print("d:", type(d))

    if len(c) != len(d):
        return "Erro: listas de tamanhos diferentes"
    resultado = []
    for i in range(len(c)):
        resultado.append(c[i] / d[i])
    print("resultado:", type(resultado))
    return resultado

# %%
lista1 = [10, 20, 30]
lista2 = [2, 4, 5]

print(dividir_listas(lista1, lista2))
# Out:
# c: <class 'list'>
# d: <class 'list'>
# resultado: <class 'list'>
# [5.0, 5.0, 6.0]

# %%
lista3 = [85, 56, 85]
lista4 = [86, 245]

print(dividir_listas(lista3, lista4))
# Out:
# c: <class 'list'>
# d: <class 'list'>
# Erro: listas de tamanhos diferentes
