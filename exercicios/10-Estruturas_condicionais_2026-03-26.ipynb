# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Dados as operações abaixo, em Python, qual o resultado da operação lógica:
# p and q and r and s and t?
# <br>
# <br>Imprima os objetos e o resultado usando uma estrutura condicional.
#
# <br>p = 2.0 + 3.0 / 5.0 == 10
# <br>q = (p + 10.2) - 5.0 * 2.0 <= 2.9
# <br>r = 10 <= p / q + 33.8 < 100
# <br>s = 5 != p / (q + r)
# <br>t = 33 == s * 2

# %%
p = 2.0 + 3.0 / 5.0 == 10
q = (p + 10.2) - 5.0 * 2.0 <= 2.9
r = 10 <= p / q + 33.8 < 100
s = 5 != p / (q + r)
t = 33 == s * 2

print(p)
print(q)
print(r)
print(s)
print(t)

if p and q and r and s and t:
    print("Verdadeiro")
else:
    print("Ao menos um falso")
# Out:
# False
# True
# True
# True
# False
# Ao menos um falso

# %% [markdown]
# ## Instancie um objeto da classe array numpy, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.
# Quantos e quais são os valores superiores a 10?

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# * R.: 1 - percorra todos os valores
#
# 2 - Para cada valor dentro do array, veja se ele é maior que 10
#
# 3a - Se sim, imprima o valor.
# 3b - Se não, não faça nada.
#
# 4- Por último, some quantos valores são maiores que 10 e imprima esse resultado.

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/lista10_exercicio3.png" width="400" />

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
import numpy as np

# %%
array_ex1 = np.random.normal(10, 3, 5)
array_ex1
# Out:
# array([10.84601349,  7.91282541,  9.54130101,  6.81461534, 12.48055784])

# %%
for valor in array_ex1:
    if valor > 10:
        print(valor)
Soma = np.sum(array_ex1 > 10)
print(f'Valores: {Soma}')
# Out:
# 10.84601349257159
# 12.480557840977811
# Valores: 2

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %%
for valor in array_ex1:
    if valor > 20:
        print(valor)
Soma = np.sum(array_ex1 > 20)
print(f'Valores: {Soma}')
# Out:
# Valores: 0

# %% [markdown]
# É possível desde que substitua o valor 10 pelo valor 20. Já que a função geradora dos dados, pega valores com média 10 e desvio-padrão 3, é pouco ou quase nada provável que tenham valores maiores que 20, mas utilizando o racional é possível.

# %% [markdown]
# ## 06 – Instancie um objeto da classe lista com os valores obtidos no exercício 02.
#
# O valor 10.453444246931676 está presente?

# %%
lista_ex6 = array_ex1.tolist()
lista_ex6
# Out:
# [10.84601349257159,
#  7.912825408242623,
#  9.541301008852905,
#  6.814615340193766,
#  12.480557840977811]

# %%
10.453444246931676 == lista_ex6
# Out:
# False

# %% [markdown]
# ## No exercício 7 da aula 6, foi instanciado um objeto da classe DataFrame. Exporte (usando nome_data_frame.to_csv(‘nome_arquivo.csv’)) para .csv estes dados e os importe (com pd.read_csv(‘nome_arquivo.csv’) aqui. Edite o objeto para que os index sejam os nomes dos genes e para que as colunas sejam facilmente identificadas. Usando o número de caracteres do primeiro gene, quero saber a informação gênica. Caso o nome tenha entre 2 e 4 caracteres inclusive, posso saber as informações do gene? Porém, caso tenha menos de 2 caracteres, posso saber todos os valores nas instâncias onde os números de caracteres dos nomes são superiores a 4? Ainda, caso tenha mais de 4 caracteres, apenas me informe quem é superior.

# %%
import pandas as pd

# %%
df_exerc7 = pd.read_csv('df_exerc7.csv', index_col=0)
df_exerc7
# Out:
#                  numero_caracteres primeiras_letras  letras_a  presenca_hu
# interleucina_6                  14               in         1        False
# interferon_gama                 15               in         2        False
# TNF-alpha                        9               TN         2        False
# interleucina_12                 15               in         1        False
# TGF-beta                         8               TG         1        False

# %% [markdown]
# ## 07 – Descreva o racional da sua resposta:

# %% [markdown]
# R.:

# %% [markdown]
# ## 08 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ## 09 – Escreva o programa em Python:

# %%
carac_gene1 = df_exerc7['numero_caracteres'].iloc[0]
carac_gene1
# Out:
# np.int64(14)

# %%
if 2 <= carac_gene1 <= 4:
    print(f'Informação do primeiro gene {df_exerc7.iloc[0]}')
elif carac_gene1 < 2:
    print(f"Genes com mais de 4 caracteres: {df_exerc7[df_exerc7['numero_caracteres'] > 4]}")
else:
    print(f"Gene com maior número de caracteres: {df_exerc7['numero_caracteres'].idxmax()}")
# Out:
# Gene com maior número de caracteres: interferon_gama

# %% [markdown]
# ## 10 – Caso a DataFrame contenha 10 milhões de entradas, este racional utilizado poderia responder as mesmas perguntas? Porque?

# %% [markdown]
# R.:
