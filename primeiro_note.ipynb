# %%
print("Python é show")
# Out:
# Python é show

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
import os
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 import pandas as pd
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
os.listdir()
# Out:
# ['.git', 'aulas', 'exercicios', 'primeiro_note.ipynb']

# %%
tupla = (1, 2, 3, 4, 5)
tupla
# Out:
# (1, 2, 3, 4, 5)

# %%
type(tupla)
# Out:
# tuple

# %%
lista = [6, 7, 8, 9, 0]
lista
# Out:
# [6, 7, 8, 9, 0]

# %%
type(lista)
# Out:
# list

# %%
dicionario = {"a":1, "b":2, "c":3, "d":4, "e":5}
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
type(dicionario)
# Out:
# dict

# %%
tupla[1]
# Out:
# 2

# %%
dicionario["d"]
# Out:
# 4

# %%
dicionario["f"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 dicionario["f"]
#
# KeyError: 'f'

# %%
print(type(lista[4]))
# Out:
# <class 'int'>

# %%
lista[-1]
# Out:
# 0

# %%
lista = [6, 7, 8, 9, 10]

# %%
lista
# Out:
# [6, 7, 8, 9, 10]

# %%
#append adiciona coisas na listas e pop exclui#

lista.append(11)

# %%
lista
# Out:
# [6, 7, 8, 9, 10, 11]

# %%
lista.pop()
# Out:
# 11

# %%
lista
# Out:
# [6, 7, 8, 9, 10]

# %%
lista.pop(1)
# Out:
# 7

# %%
lista
# Out:
# [6, 8, 9, 10]

# %%
lista = [6, 7, 8, 9, 10]

# %%
#instanciar um objeto dentro de um objeto#
novo_objeto = lista[4]

# %%
novo_objeto
# Out:
# 10

# %%
#multi-indexação de objeto composto#
a, b, c, d, e = lista
print(a, b, c, d, e)
# Out:
# 6 7 8 9 10

# %%
a
# Out:
# 6

# %%
#somar - função global: sum#
sum(lista)
# Out:
# 40

# %%
simbolo = [
    'IFNG',
    'IL10',
    'Tnf',
    'CSF2'
]
full_name = [
    'interferon gamma',
    'interleukin 10',
    'tumor necrosis factor',
    'colony stimulating factor 2'
]
source = [
    'HGNC:HGNC:5438',
    'RGD:2886',
    'MGI:MIG:104798',
    'HGNC:HGNC:2434'
]
gene_type = [
    'protein coding',
    'protein coding',
    'protein coding',
    'protein coding'
]
organism = [
    'Homo sapiens',
    'Rattus norvegicus',
    'Mus musculus',
    'Homo sapiens'
]
chromosome = [
    12,
    13,
    17,
    5
]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]
gene_matriz_lista
# Out:
# [['IFNG', 'IL10', 'Tnf', 'CSF2'],
#  ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MIG:104798', 'HGNC:HGNC:2434'],
#  ['protein coding', 'protein coding', 'protein coding', 'protein coding'],
#  ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %%
dict_gene = {
    "simbolo": simbolo,
    "full name": full_name,
    "source": source,
    "gene type": gene_type,
    "organism": organism,
    "chromosome": chromosome
}
dict_gene
# Out:
# {'simbolo': ['IFNG', 'IL10', 'Tnf', 'CSF2'],
#  'full name': ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  'source': ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MIG:104798', 'HGNC:HGNC:2434'],
#  'gene type': ['protein coding',
#   'protein coding',
#   'protein coding',
#   'protein coding'],
#  'organism': ['Homo sapiens',
#   'Rattus norvegicus',
#   'Mus musculus',
#   'Homo sapiens'],
#  'chromosome': [12, 13, 17, 5]}

# %%
import numpy as np
import pandas as pd

# %%
gene_matriz_lista
# Out:
# [['IFNG', 'IL10', 'Tnf', 'CSF2'],
#  ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MIG:104798', 'HGNC:HGNC:2434'],
#  ['protein coding', 'protein coding', 'protein coding', 'protein coding'],
#  ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %%
np.array(gene_matriz_lista)
# Out:
# array([['IFNG', 'IL10', 'Tnf', 'CSF2'],
#        ['interferon gamma', 'interleukin 10', 'tumor necrosis factor',
#         'colony stimulating factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MIG:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
gene_array = np.array(gene_matriz_lista)
gene_array
# Out:
# array([['IFNG', 'IL10', 'Tnf', 'CSF2'],
#        ['interferon gamma', 'interleukin 10', 'tumor necrosis factor',
#         'colony stimulating factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MIG:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
gene_array.shape
# Out:
# (6, 4)

# %%
gene_array[2:]
# Out:
# array([['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MIG:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
gene_array[[0,2]]
# Out:
# array([['IFNG', 'IL10', 'Tnf', 'CSF2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MIG:104798', 'HGNC:HGNC:2434']],
#       dtype='<U27')

# %%
index = [3,1,4]
gene_array[index]
# Out:
# array([['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['interferon gamma', 'interleukin 10', 'tumor necrosis factor',
#         'colony stimulating factor 2'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens']], dtype='<U27')

# %%
gene_array[:,0]
# Out:
# array(['IFNG', 'interferon gamma', 'HGNC:HGNC:5438', 'protein coding',
#        'Homo sapiens', '12'], dtype='<U27')

# %%
gene_array[:,2]
# Out:
# array(['Tnf', 'tumor necrosis factor', 'MGI:MIG:104798', 'protein coding',
#        'Mus musculus', '17'], dtype='<U27')

# %%
gene_array[-1,:]
# Out:
# array(['12', '13', '17', '5'], dtype='<U27')

# %%
gene_array[-1,1:3]
# Out:
# array(['13', '17'], dtype='<U27')
